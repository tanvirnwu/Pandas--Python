# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_column',85)
pd.set_option('display.max_row',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
people = {
    "first": ["John","Michale","Jonathon"],
    "last": ["Smith","Bary","Tott"],
    "profession": ["Student","Porfessor","Doctor"]
}

# %%
people['profession']
# Out:
# ['Student', 'Porfessor', 'Doctor']

# %%
import pandas as pd

# %%
df1= pd.DataFrame(people)

# %%
df1
# Out:
#       first   last profession
# 0      John  Smith    Student
# 1   Michale   Bary  Porfessor
# 2  Jonathon   Tott     Doctor

# %%
df1["profession"]
# Out:
# 0      Student
# 1    Porfessor
# 2       Doctor
# Name: profession, dtype: object

# %%
type(df1["profession"]) #So, it returns a series
# Out:
# pandas.core.series.Series

# %%
df1.profession
# Out:
# 0      Student
# 1    Porfessor
# 2       Doctor
# Name: profession, dtype: object

# %%
type(df1.profession)
# Out:
# pandas.core.series.Series

# %%
df1[["profession"]]
# Out:
#   profession
# 0    Student
# 1  Porfessor
# 2     Doctor

# %%
type(df1[["last", "profession"]]) #It returns aS A DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns #returns the columns of a dataset
# Out:
# Index(['first', 'last', 'profession'], dtype='object')

# %%
df1.iloc[0] #Returns the first row/valus from index 0 as a series
# Out:
# first            John
# last            Smith
# profession    Student
# Name: 0, dtype: object

# %%
df1.iloc[[0,1]] #Returns the first rows/valus from index 0 & 1 as DataFrame
# Out:
#      first   last profession
# 0     John  Smith    Student
# 1  Michale   Bary  Porfessor

# %%
df1.iloc[[0,1], 2] 

#Returns the first rows/valus from index 0 & 1 as DataFrame
#Here 2 is the column index, the profession column's index number is 2
#So it is showing only profession column as output
# Out:
# 0      Student
# 1    Porfessor
# Name: profession, dtype: object

# %%
df1.loc[0]
# Out:
# first            John
# last            Smith
# profession    Student
# Name: 0, dtype: object

# %%
df1.loc[[0,1]]
# Out:
#      first   last profession
# 0     John  Smith    Student
# 1  Michale   Bary  Porfessor

# %%
df1.loc[[0,1], 'profession']
# Out:
# 0      Student
# 1    Porfessor
# Name: profession, dtype: object

# %%
df1.loc[[0,1], ['last', 'profession']]
# Out:
#     last profession
# 0  Smith    Student
# 1   Bary  Porfessor

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.shape
# Out:
# (85, 1)

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df["Hobbyist"] #acessing a specific column
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].value_counts() #counting the values of a speicfic column
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[[1,2,3], ["Hobbyist","Dependents"]]
# Out:
#            Hobbyist Dependents
# Respondent
# 1               Yes         No
# 2                No         No
# 3               Yes        Yes

# %%
df.loc[1] #retunsall the columns for only the index 0/row 1
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
df.loc[1, "Hobbyist"]
# Out:
# 'Yes'

# %%
df.loc[[1,2,3], "Hobbyist"]
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[1:3, "Hobbyist"] #using slicing for accesing the same thing
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[1:3,['Hobbyist', 'OpenSourcer', 'OpenSource',
       'Employment']]
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time

# %%
df.loc[1:3,'Hobbyist':'Employment'] #slicing
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time

# %%
df1
# Out:
#       first   last profession
# 0      John  Smith    Student
# 1   Michale   Bary  Porfessor
# 2  Jonathon   Tott     Doctor

# %%
df1.set_index('profession')
#se_index(), set a column as index, does not effect the original Dataframe
# Out:
#                first   last
# profession
# Student         John  Smith
# Porfessor    Michale   Bary
# Doctor      Jonathon   Tott

# %%
df1
# Out:
#       first   last profession
# 0      John  Smith    Student
# 1   Michale   Bary  Porfessor
# 2  Jonathon   Tott     Doctor

# %%
df1.set_index('profession', inplace=True) #has effect on the original dataframe

# %%
df1
# Out:
#                first   last
# profession
# Student         John  Smith
# Porfessor    Michale   Bary
# Doctor      Jonathon   Tott

# %%
df1.index
# Out:
# Index(['Student', 'Porfessor', 'Doctor'], dtype='object', name='profession')

# %%
df1.loc['Student', 'last']
# Out:
# 'Smith'

# %%
df1.iloc[0]
# Out:
# first     John
# last     Smith
# Name: Student, dtype: object

# %%
df1
# Out:
#                first   last
# profession
# Student         John  Smith
# Porfessor    Michale   Bary
# Doctor      Jonathon   Tott

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#   profession     first   last
# 0    Student      John  Smith
# 1  Porfessor   Michale   Bary
# 2     Doctor  Jonathon   Tott

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df.loc['Respondent']
# Out:
# QuestionText    Randomized respondent ID number (not in order ...
# Name: Respondent, dtype: object

# %%
schema_df.loc['Respondent','QuestionText']
#Display the full texts
# Out:
# 'Randomized respondent ID number (not in order of survey response time)'

# %%
schema_df.sort_index(ascending = True) #It sorts, but not parmanently
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(inplace= True) #Now it has been sorted permanently

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# ## Filtering DataFrame

# %%
df1
# Out:
#   profession     first   last
# 0    Student      John  Smith
# 1  Porfessor   Michale   Bary
# 2     Doctor  Jonathon   Tott

# %%
filter1 = (df1['last'] == "Tott") #Creating a custom filter

# %%
filter1
# Out:
# 0    False
# 1    False
# 2     True
# Name: last, dtype: bool

# %%
df1[filter1] #Applying our custom filter on the dataframe
# Out:
#   profession     first  last
# 2     Doctor  Jonathon  Tott

# %%
df1[df1['last'] == "Tott"] #Does the same thing/ Filtering
# Out:
#   profession     first  last
# 2     Doctor  Jonathon  Tott

# %%
df1.loc[filter1]
# Out:
#   profession     first  last
# 2     Doctor  Jonathon  Tott

# %%
df1.loc[filter1,'profession']
# Out:
# 2    Doctor
# Name: profession, dtype: object

# %%
filter2 = (df1['last'] == 'Tott') & (df1['first'] == 'Jonathon')

# %%
df1[filter2]
# Out:
#   profession     first  last
# 2     Doctor  Jonathon  Tott

# %%
filter3 = (df1['last'] == 'Tott') | (df1['first'] == 'John')

# %%
df1[filter3]
# Out:
#   profession     first   last
# 0    Student      John  Smith
# 2     Doctor  Jonathon   Tott

# %%
df1[-filter3] #Here minus(-) helps to return the opposite values of the filter
# Out:
#   profession    first  last
# 1  Porfessor  Michale  Bary

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
high_salary = df['ConvertedComp'] > 70000

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp' ]]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States','India','United Kingdom','Germany','Canada']
filter4 = df['Country'].isin(countries)

# %%
df.loc[filter4, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filter5 = df['LanguageWorkedWith'].str.contains('Python', na=False)
#Filter only the rows which has "Python"

# %%
df.loc[filter5, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# ## Updating Rows & Columns

# %%
df1.columns
# Out:
# Index(['profession', 'first', 'last'], dtype='object')

# %%
df1.columns = ['first_name', 'last_name', 'profession']

# %%
df1
# Out:
#   first_name last_name profession
# 0    Student      John      Smith
# 1  Porfessor   Michale       Bary
# 2     Doctor  Jonathon       Tott

# %%
df1.columns = [x.upper() for x in df1.columns]

# %%
df1
# Out:
#   FIRST_NAME LAST_NAME PROFESSION
# 0    Student      John      Smith
# 1  Porfessor   Michale       Bary
# 2     Doctor  Jonathon       Tott

# %%
df1.columns = df1.columns.str.replace('_', ' ')

# %%
df1
# Out:
#   FIRST NAME LAST NAME PROFESSION
# 0    Student      John      Smith
# 1  Porfessor   Michale       Bary
# 2     Doctor  Jonathon       Tott

# %%
df1.columns = df1.columns.str.replace(' ', '_')

# %%
df1
# Out:
#   FIRST_NAME LAST_NAME PROFESSION
# 0    Student      John      Smith
# 1  Porfessor   Michale       Bary
# 2     Doctor  Jonathon       Tott

# %%
df1.columns = [x.lower() for x in df1.columns]

# %%
df1.columns = ['first', 'last', 'profession']

# %%
df1
# Out:
#        first      last profession
# 0    Student      John      Smith
# 1  Porfessor   Michale       Bary
# 2     Doctor  Jonathon       Tott

# %%
df1.rename(columns = {'first':'firstn', 'last':'lastn'}, inplace=True)

# %%
df1
# Out:
#       firstn     lastn profession
# 0    Student      John      Smith
# 1  Porfessor   Michale       Bary
# 2     Doctor  Jonathon       Tott

# %%
df1.loc[2] = ['John','Smith','Student']
df1.loc[0] = ['Jack','Kalis','Teacher']
df1.loc[1] = ['Mark','Wood','Businessman']

# %%
df1
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      Teacher
# 1   Mark   Wood  Businessman
# 2   John  Smith      Student

# %%
df1.loc[2, ['firstn','lastn']] = ['Jonny','Doe']

# %%
df1
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      Teacher
# 1   Mark   Wood  Businessman
# 2  Jonny    Doe      Student

# %%
df1.loc[2, 'profession'] = 'Doctor'

# %%
df1
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      Teacher
# 1   Mark   Wood  Businessman
# 2  Jonny    Doe       Doctor

# %%
df1.at[2, 'profession'] = 'Actor'

# %%
df1
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      Teacher
# 1   Mark   Wood  Businessman
# 2  Jonny    Doe        Actor

# %% [markdown]
# ### Updating multiple rows

# %%
df1
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      Teacher
# 1   Mark   Wood  Businessman
# 2  Jonny    Doe        Actor

# %%
df1['profession'].str.lower()
# Out:
# 0        teacher
# 1    businessman
# 2          actor
# Name: profession, dtype: object

# %%
df1 #The original datframe hasn't change
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      Teacher
# 1   Mark   Wood  Businessman
# 2  Jonny    Doe        Actor

# %%
df1['profession'] =  df1['profession'].str.lower()

# %%
df1  #The oroginal dataframe has changed
# Out:
#   firstn  lastn   profession
# 0   Jack  Kalis      teacher
# 1   Mark   Wood  businessman
# 2  Jonny    Doe        actor

# %% [markdown]
# __apply__
#
# __map__
#
# __applymap__
#
# __replace__

# %%
df1['profession'].apply(len)
# Out:
# 0     7
# 1    11
# 2     5
# Name: profession, dtype: int64

# %%
df1['email'] = ['jack@email.com', 'mark@email.com', 'jonny@email.com']

# %%
df1
# Out:
#   firstn  lastn   profession            email
# 0   Jack  Kalis      teacher   jack@email.com
# 1   Mark   Wood  businessman   mark@email.com
# 2  Jonny    Doe        actor  jonny@email.com

# %%
df1['email'].apply(len)
# Out:
# 0    14
# 1    14
# 2    15
# Name: email, dtype: int64

# %%
def update_email1(email):
    return email.upper()

# %%
df1['email'].apply(update_email1)
# Out:
# 0     JACK@EMAIL.COM
# 1     MARK@EMAIL.COM
# 2    JONNY@EMAIL.COM
# Name: email, dtype: object

# %%
df1['email'] = df1['email'].apply(update_email1)

# %%
df1
# Out:
#   firstn  lastn   profession            email
# 0   Jack  Kalis      teacher   JACK@EMAIL.COM
# 1   Mark   Wood  businessman   MARK@EMAIL.COM
# 2  Jonny    Doe        actor  JONNY@EMAIL.COM

# %%
df1['email'] = df1['email'].apply(lambda x: x.lower())

# %%
df1
# Out:
#   firstn  lastn   profession            email
# 0   Jack  Kalis      teacher   jack@email.com
# 1   Mark   Wood  businessman   mark@email.com
# 2  Jonny    Doe        actor  jonny@email.com

# %%
df1['email'].apply(len)
# Out:
# 0    14
# 1    14
# 2    15
# Name: email, dtype: int64

# %%
df1.apply(len)
# Out:
# firstn        3
# lastn         3
# profession    3
# email         3
# dtype: int64

# %%
len(df1['email'])
# Out:
# 3

# %%
df1.apply(len, axis='rows')
# Out:
# firstn        3
# lastn         3
# profession    3
# email         3
# dtype: int64

# %%
df1.apply(len, axis='columns')
# Out:
# 0    4
# 1    4
# 2    4
# dtype: int64

# %%
 df1.apply(pd.Series.min)
# Out:
# firstn                  Jack
# lastn                    Doe
# profession             actor
# email         jack@email.com
# dtype: object

# %%
df1.apply(lambda  x: x.min())
# Out:
# firstn                  Jack
# lastn                    Doe
# profession             actor
# email         jack@email.com
# dtype: object

# %%
df1.applymap(len)
# Out:
#    firstn  lastn  profession  email
# 0       4      5           7     14
# 1       4      4          11     14
# 2       5      3           5     15

# %%
df1.applymap(str.lower)
# Out:
#   firstn  lastn   profession            email
# 0   jack  kalis      teacher   jack@email.com
# 1   mark   wood  businessman   mark@email.com
# 2  jonny    doe        actor  jonny@email.com

# %%
df1['firstn'].map({'Jack':'Chris', 'Mark':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: firstn, dtype: object

# %%
df1
# Out:
#   firstn  lastn   profession            email
# 0   Jack  Kalis      teacher   jack@email.com
# 1   Mark   Wood  businessman   mark@email.com
# 2  Jonny    Doe        actor  jonny@email.com

# %%
df1['firstn'] = df1['firstn'].replace({'Jack':'Chris', 'Mark':'Mary'})

# %%
df1
# Out:
#   firstn  lastn   profession            email
# 0  Chris  Kalis      teacher   jack@email.com
# 1   Mary   Wood  businessman   mark@email.com
# 2  Jonny    Doe        actor  jonny@email.com

# %% [markdown]
# ### Rename a Columns

# %%
#Rename a Columns
df.rename(columns= {'ConvertedComp':'SalaryUSD'}, inplace = True)

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No': False})
#Updated the column labels

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df2 = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df1 = pd.read_csv('survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_column',85)
pd.set_option('display.max_row',85)

# %%
df.loc[:, 'Hobbyist'] = df2['Hobbyist']

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No': False})
#Updated the column labels

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# ## Add/Remove Columns & Rows

# %%
df1
# Out:
#   firstn  lastn   profession            email
# 0  Chris  Kalis      teacher   jack@email.com
# 1   Mary   Wood  businessman   mark@email.com
# 2  Jonny    Doe        actor  jonny@email.com

# %%
df1['firstn'] + ' ' + df1['lastn']
# Out:
# 0    Chris Kalis
# 1      Mary Wood
# 2      Jonny Doe
# dtype: object

# %%
df1['fulln'] = df1['firstn'] + ' ' + df1['lastn']

# %%
df1
# Out:
#   firstn  lastn   profession            email        fulln
# 0  Chris  Kalis      teacher   jack@email.com  Chris Kalis
# 1   Mary   Wood  businessman   mark@email.com    Mary Wood
# 2  Jonny    Doe        actor  jonny@email.com    Jonny Doe

# %%
def add_coll (rows):
    return rows['firstn'] + ' ' + rows['lastn']

# %%
df1['full_name']=df1.apply(add_coll, axis=1)

# %%
df1
# Out:
#   firstn  lastn   profession            email        fulln    full_name
# 0  Chris  Kalis      teacher   jack@email.com  Chris Kalis  Chris Kalis
# 1   Mary   Wood  businessman   mark@email.com    Mary Wood    Mary Wood
# 2  Jonny    Doe        actor  jonny@email.com    Jonny Doe    Jonny Doe

# %%
df1.drop(columns = ['firstn','lastn'], inplace=True)

# %%
df1
# Out:
#     profession            email        fulln
# 0      teacher   jack@email.com  Chris Kalis
# 1  businessman   mark@email.com    Mary Wood
# 2        actor  jonny@email.com    Jonny Doe

# %%
df1['fulln'].str.split(' ', expand=True)
# Out:
#        0      1
# 0  Chris  Kalis
# 1   Mary   Wood
# 2  Jonny    Doe

# %%
df1[['firstn','lastn']] = df1['fulln'].str.split(' ', expand=True)

# %%
df1
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2        actor  jonny@email.com    Jonny Doe  Jonny    Doe

# %%
df1.append({'firstn':'Tony'}, ignore_index=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6812\2482402293.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append({'firstn':'Tony'}, ignore_index=True)
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2        actor  jonny@email.com    Jonny Doe  Jonny    Doe
# 3          NaN              NaN          NaN   Tony    NaN

# %%
df1
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2        actor  jonny@email.com    Jonny Doe  Jonny    Doe

# %%
people = {
    "firstn": ["Tony","Stark"],
    "lastn": ["Steve","Jobs"],
    "email": ["tony@email.com","steve@email.com"]
}

df2= pd.DataFrame(people)

# %%
df2
# Out:
#   firstn  lastn            email
# 0   Tony  Steve   tony@email.com
# 1  Stark   Jobs  steve@email.com

# %%
#add the rows of df2 with df1
df1.append(df2, ignore_index=True, sort=False)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6812\2708895873.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2, ignore_index=True, sort=False)
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2        actor  jonny@email.com    Jonny Doe  Jonny    Doe
# 3          NaN   tony@email.com          NaN   Tony  Steve
# 4          NaN  steve@email.com          NaN  Stark   Jobs

# %%
df1=df1.append(df2, ignore_index=True, sort=False)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6812\2582763558.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(df2, ignore_index=True, sort=False)

# %%
df1
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2        actor  jonny@email.com    Jonny Doe  Jonny    Doe
# 3          NaN   tony@email.com          NaN   Tony  Steve
# 4          NaN  steve@email.com          NaN  Stark   Jobs

# %%
df1.drop(index=4)
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2        actor  jonny@email.com    Jonny Doe  Jonny    Doe
# 3          NaN   tony@email.com          NaN   Tony  Steve

# %%
df1.drop(index=df1[df1['lastn']=='Doe'].index)
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 3          NaN   tony@email.com          NaN   Tony  Steve
# 4          NaN  steve@email.com          NaN  Stark   Jobs

# %%
filter5 = df1['lastn']=='Doe'

# %%
df1.drop(index=df1[filter5].index, inplace=True)

# %%
df1
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 3          NaN   tony@email.com          NaN   Tony  Steve
# 4          NaN  steve@email.com          NaN  Stark   Jobs

# %% [markdown]
# ## Sorting Data

# %%
df1.sort_values(by='lastn', ascending=True)
# Out:
#     profession            email        fulln firstn  lastn
# 4          NaN  steve@email.com          NaN  Stark   Jobs
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 3          NaN   tony@email.com          NaN   Tony  Steve
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood

# %%
df1=df1.append({'firstn':'Michale', 'lastn':'Wood'},ignore_index=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6812\4070300505.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append({'firstn':'Michale', 'lastn':'Wood'},ignore_index=True)

# %%
df1
# Out:
#     profession            email        fulln   firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis    Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood     Mary   Wood
# 2          NaN   tony@email.com          NaN     Tony  Steve
# 3          NaN  steve@email.com          NaN    Stark   Jobs
# 4          NaN              NaN          NaN    Stark  Clark
# 5          NaN              NaN          NaN  Michale   Wood

# %%
df1.sort_values(by=['lastn','firstn'], ascending=True)
# Out:
#     profession            email        fulln   firstn  lastn
# 4          NaN              NaN          NaN    Stark  Clark
# 3          NaN  steve@email.com          NaN    Stark   Jobs
# 0      teacher   jack@email.com  Chris Kalis    Chris  Kalis
# 2          NaN   tony@email.com          NaN     Tony  Steve
# 1  businessman   mark@email.com    Mary Wood     Mary   Wood
# 5          NaN              NaN          NaN  Michale   Wood

# %%
df1.loc[5,'firstn'] = 'Jack'

# %%
df1
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2          NaN   tony@email.com          NaN   Tony  Steve
# 3          NaN  steve@email.com          NaN  Stark   Jobs
# 4          NaN              NaN          NaN  Stark  Clark
# 5          NaN              NaN          NaN   Jack   Wood

# %%
df1.sort_values(by=['lastn','firstn'], ascending=True)
# Out:
#     profession            email        fulln firstn  lastn
# 4          NaN              NaN          NaN  Stark  Clark
# 3          NaN  steve@email.com          NaN  Stark   Jobs
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 2          NaN   tony@email.com          NaN   Tony  Steve
# 5          NaN              NaN          NaN   Jack   Wood
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood

# %%
df1.sort_values(by=['lastn','firstn'], ascending=[False,  True], inplace=True)

# %%
df1
# Out:
#     profession            email        fulln firstn  lastn
# 5          NaN              NaN          NaN   Jack   Wood
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2          NaN   tony@email.com          NaN   Tony  Steve
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 3          NaN  steve@email.com          NaN  Stark   Jobs
# 4          NaN              NaN          NaN  Stark  Clark

# %%
df1.sort_index()
# Out:
#     profession            email        fulln firstn  lastn
# 0      teacher   jack@email.com  Chris Kalis  Chris  Kalis
# 1  businessman   mark@email.com    Mary Wood   Mary   Wood
# 2          NaN   tony@email.com          NaN   Tony  Steve
# 3          NaN  steve@email.com          NaN  Stark   Jobs
# 4          NaN              NaN          NaN  Stark  Clark
# 5          NaN              NaN          NaN   Jack   Wood

# %%
df.sort_values(by='Country', inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(3)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending =[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(3)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0

# %%
df['SalaryUSD'].nlargest(5)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(5, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# 87896                                 Less than once per year
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
df.nsmallest(5, 'SalaryUSD')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 28638       I am a developer by profession      True
# 722         I am a developer by profession     False
# 13825       I am a developer by profession      True
# 40913       I am a developer by profession      True
# 30630       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# 722         Less than once a month but more than once per ...
# 13825                                                   Never
# 40913                                 Less than once per year
# 30630       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 28638       OSS is, on average, of HIGHER quality than pro...
# 722         The quality of OSS and closed source software ...
# ...
